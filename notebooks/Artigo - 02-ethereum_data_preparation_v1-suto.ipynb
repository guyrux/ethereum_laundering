# %% [markdown]
# # Data preparation - ethereum - v1

# %% [markdown]
# # Setup
#
# ## Library import
# We import all the required Python libraries

# %%
import os

# Data manipulation
from feature_engine.encoding import RareLabelEncoder, CountFrequencyEncoder
from feature_engine.imputation import MeanMedianImputer
import pandas as pd
import numpy as np

# Visualizations
import plotly
import plotly.graph_objs as go
import plotly.offline as ply
plotly.offline.init_notebook_mode(connected=True)
import matplotlib as plt

from tqdm import tqdm
from lightgbm import (
    LGBMClassifier, plot_importance, create_tree_digraph, plot_tree
)
import missingno as msno
# from pycaret.classification import ClassificationExperiment
from sklearn.pipeline import Pipeline
from sklearn.model_selection import (
    train_test_split
    , cross_val_score
    , StratifiedKFold
    , StratifiedShuffleSplit
    , cross_validate
    , GridSearchCV
)
# from ydata_profiling import ProfileReport
from sklearn.metrics import (
    confusion_matrix, classification_report, ConfusionMatrixDisplay, roc_auc_score, roc_curve
)

# Autoreload extension
if 'autoreload' not in get_ipython().extension_manager.loaded:
    # %load_ext autoreload
    
# %autoreload 2

# Options for pandas
# pd.options.display.max_columns = None
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.float_format', '{:.5f}'.format)
# pd.options.display.float_format = '{:.5f}'.format
# pd.options.display.max_rows = 120
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Local library import
# We import all the required local libraries libraries

# %%
os.chdir('../')
from src.utils.data_describe import breve_descricao, serie_nulos, cardinalidade, check_for_equal_columns
os.chdir('./notebooks/')

# %% [markdown]
# # Parameter definition
# We set all relevant parameters for our notebook. By convention, parameters are uppercase, while all the
# other variables follow Python's guidelines.

# %%
RAW_FOLDER = '../data/raw/'
INTERIM_FOLDER = '../data/interim/'
PROCESSED_FOLDER = '../data/processed/'
REPORTS_FOLDER = '../reports/'
RANDOM_STATE = 42

# %% [markdown]
# ## Custom functions

# %%
def rename_columns(df: pd.DataFrame) -> pd.DataFrame:
    df_temp = df.copy()
    lst_columns = [column.strip().replace(' ', '_') for column in df_temp.columns]
    df_temp.columns = lst_columns
    return df_temp


def load_file_into_df(file_path: str) -> pd.DataFrame:
    filename_with_ext = file_path.split('/')[-1].split('\\')[-1]

    if '.' in filename_with_ext:
        file_name = filename_with_ext.split('.')[-2]
        extension = filename_with_ext.split('.')[-1]
    else:
        file_name = filename_with_ext
        extension = ''

    try:
        df_raw = pd.read_parquet(INTERIM_FOLDER + f'{file_name}.pqt')
        print(f'PARQUET file loaded. Shape: {df_raw.shape}')
    except FileNotFoundError as e:
        df_raw = pd.read_csv(RAW_FOLDER + f'{file_name}.csv', index_col=0)
        df_raw.drop(columns=['Index'], inplace=True)
        df_raw = rename_columns(df_raw)
        df_raw.to_parquet(INTERIM_FOLDER +  f'{file_name}.pqt', index=False)
        print(f'EXCEL file loaded and PARQUET created. Shape: {df_raw.shape}')
    return df_raw


def list_equal_columns(df: pd. DataFrame, verbose: bool = False) -> tuple[list, dict]:
    dct_equal_columns = {}
    lst_equal_columns = []

    for i, column_to_test in enumerate(df.columns, start=1):
        lst_equal_columns_temp = []
        for column in [column for column in df.columns[i:] if column not in lst_equal_columns]:
            is_equal = df[column_to_test].equals(df[column])
            if is_equal:
                lst_equal_columns_temp.append(column)
                lst_equal_columns.append(column)
                if verbose:
                    print(f'{column_to_test} is EQUAL to {column}.')
        if len(lst_equal_columns_temp) > 0:
            dct_equal_columns[column_to_test] = lst_equal_columns_temp

    return lst_equal_columns, dct_equal_columns


def drop_unitary_columns(df: pd.DataFrame, verbose: bool = False) -> tuple[pd.DataFrame, list]:
    lst_unitary_columns = []
    df_temp = df.copy()

    for column in df_temp.columns:
        if len(df_temp[column].value_counts()) == 1:
            df_temp.drop(columns=[column], inplace=True)
            lst_unitary_columns.append(column)

    if verbose:
        print(f'Removed columns: {lst_unitary_columns}\n')

    return df_temp, lst_unitary_columns

# %% [markdown]
# # Data import
# We retrieve all the required data for the analysis.

# %%
df_raw = load_file_into_df(file_path='transaction_dataset.csv')

display(df_raw.head(3))
# Out:
# PARQUET file loaded. Shape: (9841, 49)
#                                       Address  FLAG  Avg_min_between_sent_tnx  \
# 0  0x00009277775ac7d0d59eaad8fee3d10ac6c805e8     0                 844.26000
# 1  0x0002b44ddb1476db43c868bd494422ee4c136fed     0               12709.07000
# 2  0x0002bda54cb772d040f779e88eb453cac0daa244     0              246194.54000
#
#    Avg_min_between_received_tnx  Time_Diff_between_first_and_last_(Mins)  \
# 0                    1093.71000                             704785.63000
# 1                    2958.44000                            1218216.73000
# 2                    2434.02000                             516729.30000
#
#    Sent_tnx  Received_Tnx  Number_of_Created_Contracts  \
# 0       721            89                            0
# 1        94             8                            0
# 2         2            10                            0
#
#    Unique_Received_From_Addresses  Unique_Sent_To_Addresses  \
# 0                              40                       118
# 1                               5                        14
# 2                              10                         2
#
#    min_value_received  max_value_received  avg_val_received  min_val_sent  \
# 0             0.00000            45.80678           6.58951       0.00000
# 1             0.00000             2.61327           0.38569       0.00000
# 2             0.11312             1.16545           0.35891       0.05000
#
#    max_val_sent  avg_val_sent  min_value_sent_to_contract  \
# 0      31.22000       1.20068                     0.00000
# 1       1.80000       0.03284                     0.00000
# 2       3.53862       1.79431                     0.00000
#
#    max_val_sent_to_contract  avg_value_sent_to_contract  \
# 0                   0.00000                     0.00000
# 1                   0.00000                     0.00000
# 2                   0.00000                     0.00000
#
#    total_transactions_(including_tnx_to_create_contract  total_Ether_sent  \
# 0                                                   810         865.69109
# 1                                                   102           3.08730
# 2                                                    12           3.58862
#
#    total_ether_received  total_ether_sent_contracts  total_ether_balance  \
# 0             586.46667                     0.00000           -279.22442
# 1               3.08548                     0.00000             -0.00182
# 2               3.58906                     0.00000              0.00044
#
#    Total_ERC20_tnxs  ERC20_total_Ether_received  ERC20_total_ether_sent  \
# 0         265.00000              35588543.78000          35603169.52000
# 1           8.00000                   403.42831                 2.26081
# 2           8.00000                   521.51207                 0.00000
#
#    ERC20_total_Ether_sent_contract  ERC20_uniq_sent_addr  ERC20_uniq_rec_addr  \
# 0                          0.00000              30.00000             54.00000
# 1                          0.00000               1.00000              5.00000
# 2                          0.00000               0.00000              7.00000
#
#    ERC20_uniq_sent_addr.1  ERC20_uniq_rec_contract_addr  \
# 0                 0.00000                      58.00000
# 1                 0.00000                       7.00000
# 2                 0.00000                       8.00000
#
#    ERC20_avg_time_between_sent_tnx  ERC20_avg_time_between_rec_tnx  \
# 0                          0.00000                         0.00000
# 1                          0.00000                         0.00000
# 2                          0.00000                         0.00000
#
#    ERC20_avg_time_between_rec_2_tnx  ERC20_avg_time_between_contract_tnx  \
# 0                           0.00000                              0.00000
# 1                           0.00000                              0.00000
# 2                           0.00000                              0.00000
#
#    ERC20_min_val_rec  ERC20_max_val_rec  ERC20_avg_val_rec  \
# 0            0.00000     15000000.00000       265586.14760
# 1            0.00000          365.00000           57.63262
# 2            0.00000          442.81984           65.18901
#
#    ERC20_min_val_sent  ERC20_max_val_sent  ERC20_avg_val_sent  \
# 0             0.00000      16830998.35000        271779.92000
# 1             2.26081             2.26081             2.26081
# 2             0.00000             0.00000             0.00000
#
#    ERC20_min_val_sent_contract  ERC20_max_val_sent_contract  \
# 0                      0.00000                      0.00000
# 1                      0.00000                      0.00000
# 2                      0.00000                      0.00000
#
#    ERC20_avg_val_sent_contract  ERC20_uniq_sent_token_name  \
# 0                      0.00000                    39.00000
# 1                      0.00000                     1.00000
# 2                      0.00000                     0.00000
#
#    ERC20_uniq_rec_token_name ERC20_most_sent_token_type  \
# 0                   57.00000                  Cofoundit
# 1                    7.00000             Livepeer Token
# 2                    8.00000                       None
#
#   ERC20_most_rec_token_type
# 0                 Numeraire
# 1            Livepeer Token
# 2                     XENON

# %% [markdown]
# # Data cleaning
#
# 1. Remove duplicated registries
# 2. Remove duplicated columns
# 3. Remove constant columns
# 4. Remove equal columns
# 5. Transforming categorical features

# %% [markdown]
# ## Removing duplicated registries

# %%
df_cleaned = df_raw.copy()

df_cleaned.drop_duplicates(inplace=True)

print(f'Shape before data cleasing: {df_raw.shape}')
print(f'After dropping duplicated rows: {df_cleaned.shape}')
# Out:
# Shape before data cleasing: (9841, 49)
# After dropping duplicated rows: (9823, 49)

# %% [markdown]
# ### Removing duplicated wallet with different 'FLAG'

# %%
print(f'Shape before dropping duplicated wallet: {df_cleaned.shape}')

df_cleaned.sort_values(by=['Address', 'FLAG'], ascending=[True, False])

df_cleaned.drop_duplicates(subset=['Address', 'FLAG'], keep='first', inplace=True)

print(f'After dropping dropping duplicated wallet: {df_cleaned.shape}')
# Out:
# Shape before dropping duplicated wallet: (9823, 49)
# After dropping dropping duplicated wallet: (9816, 49)

# %% [markdown]
# ## Removing duplicated columns

# %%
print(f'Shape before dropping duplicated columns: {df_cleaned.shape}')

dct_equal_columns = list_equal_columns(df_cleaned, verbose=True)[1]

for key, lst_to_drop in dct_equal_columns.items():
    df_cleaned.drop(columns=lst_to_drop, inplace=True)

print(f'Shape AFTER dropping duplicated columns: {df_cleaned.shape}')
# Out:
# Shape before dropping duplicated columns: (9816, 49)
# ERC20_avg_time_between_sent_tnx is EQUAL to ERC20_avg_time_between_rec_tnx.
# ERC20_avg_time_between_sent_tnx is EQUAL to ERC20_avg_time_between_rec_2_tnx.
# ERC20_avg_time_between_sent_tnx is EQUAL to ERC20_avg_time_between_contract_tnx.
# ERC20_avg_time_between_sent_tnx is EQUAL to ERC20_min_val_sent_contract.
# ERC20_avg_time_between_sent_tnx is EQUAL to ERC20_max_val_sent_contract.
# ERC20_avg_time_between_sent_tnx is EQUAL to ERC20_avg_val_sent_contract.
# Shape AFTER dropping duplicated columns: (9816, 43)

# %% [markdown]
# ## Removing constant columns

# %%
df_cleaned = drop_unitary_columns(df_cleaned, verbose=True)[0]

print(f'Shape before data cleasing: {df_raw.shape}')
print(f'After dropping duplicated columns: {df_cleaned.shape}')
# Out:
# Removed columns: ['ERC20_avg_time_between_sent_tnx']
#
# Shape before data cleasing: (9841, 49)
# After dropping duplicated columns: (9816, 42)

# %% [markdown]
# ## Pre-processing categorical features

# %% [markdown]
# ### Replacing "    " and "0" to "no information"

# %%
for column in ['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']:
    df_cleaned.loc[df_cleaned[column].isnull(), column] = "0"
    for category in [" ", "", "0"]:
        df_cleaned[column] = df_cleaned[column].str.strip()
        df_cleaned[column].replace(category, "no information", inplace=True)
    

    display(
        pd.DataFrame(
            100*df_cleaned.loc[:, column].value_counts(normalize=True)
        ).head(10)
    )
# Out:
# C:\Users\gusta\AppData\Local\Temp\ipykernel_20276\2465453263.py:5: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#                                proportion
# ERC20_most_sent_token_type
# no information                   84.22983
# EOS                               1.40587
# OmiseGO                           1.38549
# Golem                             1.31418
# blockwell.ai KYC Casper Token     1.29381
# StatusNetwork                     0.62143
# BAT                               0.38712
# Qtum                              0.34637
# Bancor                            0.32600
# Reputation                        0.26487
# C:\Users\gusta\AppData\Local\Temp\ipykernel_20276\2465453263.py:5: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#                            proportion
# ERC20_most_rec_token_type
# no information               53.78973
# OmiseGO                       8.85289
# Blockwell say NOTSAFU         7.93602
# DATAcoin                      3.63692
# Livepeer Token                2.07824
# EOS                           1.64018
# XENON                         1.47718
# Golem                         1.28362
# GSENetwork                    0.81500
# Tronix                        0.77425

# %% [markdown]
# # Experiment 01 - Only numerical features

# %%
df_cleaned_exp_01 = df_cleaned.drop(columns=['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']).copy()

# %% [markdown]
# ## Splitting data set

# %%
test_size = 0.15
train_size = 1 - test_size

lst_test_sample = df_cleaned_exp_01.sample(int(test_size*len(df_cleaned_exp_01)), random_state=RANDOM_STATE).index.values
lst_train_sample = df_cleaned_exp_01.drop(index=lst_test_sample).index.values

print(f"""
test_size: {test_size}
test_sample (registries): {len(lst_test_sample)}

train_size: {train_size}
train_sample (registries): {len(lst_train_sample)}
""")

df_cleaned_exp_01.loc[lst_train_sample, :].head()
# Out:
# test_size: 0.15
# test_sample (registries): 1472
#
# train_size: 0.85
# train_sample (registries): 8344
#                                       Address  FLAG  Avg_min_between_sent_tnx  \
# 1  0x0002b44ddb1476db43c868bd494422ee4c136fed     0               12709.07000
# 2  0x0002bda54cb772d040f779e88eb453cac0daa244     0              246194.54000
# 4  0x00062d1dd1afb6fb02540ddad9cdebfe568e0d89     0                  36.61000
# 5  0x000895ad78f4403ecd9468900e68d6ee506136fd     0                9900.12000
# 6  0x000d63fc5df52b0204374c2f5a3249779805d5d1     0                  69.46000
#
#    Avg_min_between_received_tnx  Time_Diff_between_first_and_last_(Mins)  \
# 1                    2958.44000                            1218216.73000
# 2                    2434.02000                             516729.30000
# 4                   10707.77000                             382472.42000
# 5                     375.48000                              20926.68000
# 6                     629.44000                               8660.35000
#
#    Sent_tnx  Received_Tnx  Number_of_Created_Contracts  \
# 1        94             8                            0
# 2         2            10                            0
# 4      4598            20                            1
# 5         2             3                            0
# 6        25            11                            0
#
#    Unique_Received_From_Addresses  Unique_Sent_To_Addresses  \
# 1                               5                        14
# 2                              10                         2
# 4                               7                        19
# 5                               2                         1
# 6                               9                        20
#
#    min_value_received  max_value_received  avg_val_received  min_val_sent  \
# 1             0.00000             2.61327           0.38569       0.00000
# 2             0.11312             1.16545           0.35891       0.05000
# 4             0.00000            12.80241           2.67110       0.00000
# 5             0.72415             4.81378           3.23491       4.16680
# 6             0.04900             2.65000           1.09811       0.00946
#
#    max_val_sent  avg_val_sent  min_value_sent_to_contract  \
# 1       1.80000       0.03284                     0.00000
# 2       3.53862       1.79431                     0.00000
# 4       9.00000       0.02269                     0.00000
# 5       5.53692       4.85186                     0.00000
# 6       4.28479       0.48250                     0.00000
#
#    max_val_sent_to_contract  avg_value_sent_to_contract  \
# 1                   0.00000                     0.00000
# 2                   0.00000                     0.00000
# 4                   0.00000                     0.00000
# 5                   0.00000                     0.00000
# 6                   0.00000                     0.00000
#
#    total_transactions_(including_tnx_to_create_contract  total_Ether_sent  \
# 1                                                   102           3.08730
# 2                                                    12           3.58862
# 4                                                  4619         104.31888
# 5                                                     5           9.70372
# 6                                                    36          12.06239
#
#    total_ether_received  total_ether_sent_contracts  total_ether_balance  \
# 1               3.08548                     0.00000             -0.00182
# 2               3.58906                     0.00000              0.00044
# 4              53.42190                     0.00000            -50.89699
# 5               9.70472                     0.00000              0.00101
# 6              12.07927                     0.00000              0.01687
#
#    Total_ERC20_tnxs  ERC20_total_Ether_received  ERC20_total_ether_sent  \
# 1           8.00000                   403.42831                 2.26081
# 2           8.00000                   521.51207                 0.00000
# 4          42.00000                162829.66090            123539.93290
# 5           0.00000                     0.00000                 0.00000
# 6           0.00000                     0.00000                 0.00000
#
#    ERC20_total_Ether_sent_contract  ERC20_uniq_sent_addr  ERC20_uniq_rec_addr  \
# 1                          0.00000               1.00000              5.00000
# 2                          0.00000               0.00000              7.00000
# 4                          0.00000               4.00000             23.00000
# 5                          0.00000               0.00000              0.00000
# 6                          0.00000               0.00000              0.00000
#
#    ERC20_uniq_sent_addr.1  ERC20_uniq_rec_contract_addr  ERC20_min_val_rec  \
# 1                 0.00000                       7.00000            0.00000
# 2                 0.00000                       8.00000            0.00000
# 4                 0.00000                      27.00000            0.00000
# 5                 0.00000                       0.00000            0.00000
# 6                 0.00000                       0.00000            0.00000
#
#    ERC20_max_val_rec  ERC20_avg_val_rec  ERC20_min_val_sent  \
# 1          365.00000           57.63262             2.26081
# 2          442.81984           65.18901             0.00000
# 4        90000.00000         4934.23215             0.00000
# 5            0.00000            0.00000             0.00000
# 6            0.00000            0.00000             0.00000
#
#    ERC20_max_val_sent  ERC20_avg_val_sent  ERC20_uniq_sent_token_name  \
# 1             2.26081             2.26081                     1.00000
# 2             0.00000             0.00000                     0.00000
# 4         45000.00000         13726.65922                     6.00000
# 5             0.00000             0.00000                     0.00000
# 6             0.00000             0.00000                     0.00000
#
#    ERC20_uniq_rec_token_name
# 1                    7.00000
# 2                    8.00000
# 4                   27.00000
# 5                    0.00000
# 6                    0.00000

# %% [markdown]
# ## Exporting

# %%
df_cleaned_exp_01.loc[lst_train_sample, :].to_parquet(INTERIM_FOLDER + 'artigo_df_train_exp_01.pqt')
df_cleaned_exp_01.loc[lst_test_sample, :].to_parquet(INTERIM_FOLDER + 'artigo_df_test_exp_01.pqt')

# %% [markdown]
# # Experiment 02 - Categorical features encoded by frequency

# %%
df_cleaned_exp_02 = df_cleaned.copy()
df_cleaned_exp_02.shape
# Out:
# (9816, 42)

# %%
df_temp = df_cleaned_exp_02.drop(columns=['Address', 'FLAG'])

df_temp = cardinalidade(df_temp.select_dtypes(include=[float, int]))
df_temp['Proporção Nulos'].value_counts()
# Out:
# c:\PROJETOS NO GIT\Tsu\ethereum_laundering\src\utils\data_describe.py:67: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# c:\PROJETOS NO GIT\Tsu\ethereum_laundering\src\utils\data_describe.py:67: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# c:\PROJETOS NO GIT\Tsu\ethereum_laundering\src\utils\data_describe.py:67: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# c:\PROJETOS NO GIT\Tsu\ethereum_laundering\src\utils\data_describe.py:67: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# c:\PROJETOS NO GIT\Tsu\ethereum_laundering\src\utils\data_describe.py:67: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#
# c:\PROJETOS NO GIT\Tsu\ethereum_laundering\src\utils\data_describe.py:67: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# Proporção Nulos
# 0.00000    22
# 0.08445    16
# Name: count, dtype: int64

# %% [markdown]
# ## Splitting data set

# %%
test_size = 0.15
train_size = 1 - test_size

X = df_cleaned_exp_02.drop(columns=['Address', 'FLAG']).copy()
y = df_cleaned_exp_02[['FLAG']]

df_cleaned_train_exp_02, df_cleaned_test_exp_02 = train_test_split(
    df_cleaned_exp_02.drop(columns=['Address']), train_size=train_size, 
    random_state=RANDOM_STATE,
)

print(f"""
test_size: {test_size}
test_sample (registries): {len(df_cleaned_test_exp_02)}
test_sample's target's proportion:
{df_cleaned_test_exp_02['FLAG'].value_counts(normalize=True)}

train_size: {train_size}
train_sample (registries): {len(df_cleaned_train_exp_02)}
train_sample's target's proportion:
{df_cleaned_train_exp_02['FLAG'].value_counts(normalize=True)}
""")

df_cleaned_train_exp_02.head()
# Out:
# test_size: 0.15
# test_sample (registries): 1473
# test_sample's target's proportion:
# FLAG
# 0   0.77733
# 1   0.22267
# Name: proportion, dtype: float64
#
# train_size: 0.85
# train_sample (registries): 8343
# train_sample's target's proportion:
# FLAG
# 0   0.77814
# 1   0.22186
# Name: proportion, dtype: float64
#       FLAG  Avg_min_between_sent_tnx  Avg_min_between_received_tnx  \
# 2859     0                 163.07000                       0.17000
# 2149     0                   0.00000                       4.64000
# 2979     0                1050.50000                     887.86000
# 185      0                 136.47000                  482175.49000
# 1002     0                   0.00000                    1417.28000
#
#       Time_Diff_between_first_and_last_(Mins)  Sent_tnx  Received_Tnx  \
# 2859                                326.47000         2             2
# 2149                               2726.18000         1             2
# 2979                            1393223.92000       689           754
# 185                              964896.88000         4             2
# 1002                             226764.50000         0           160
#
#       Number_of_Created_Contracts  Unique_Received_From_Addresses  \
# 2859                            0                               2
# 2149                            0                               1
# 2979                            0                             405
# 185                             0                               2
# 1002                            1                               4
#
#       Unique_Sent_To_Addresses  min_value_received  max_value_received  \
# 2859                         2            35.49665            65.50334
# 2149                         1             0.01500             6.90985
# 2979                       448             0.00000            81.82880
# 185                          3             0.12225            30.00000
# 1002                         0             0.00000             6.87895
#
#       avg_val_received  min_val_sent  max_val_sent  avg_val_sent  \
# 2859          50.50000       3.00000      97.99902      50.49951
# 2149           3.46242       6.92436       6.92436       6.92436
# 2979           1.66417       0.00000      59.98000       1.52056
# 185           15.06113       0.00069      29.39944       7.53027
# 1002           2.69873       0.00000       0.00000       0.00000
#
#       min_value_sent_to_contract  max_val_sent_to_contract  \
# 2859                     0.00000                   0.00000
# 2149                     0.00000                   0.00000
# 2979                     0.00000                   0.00000
# 185                      0.00000                   0.00000
# 1002                     0.00000                   0.00000
#
#       avg_value_sent_to_contract  \
# 2859                     0.00000
# 2149                     0.00000
# 2979                     0.00000
# 185                      0.00000
# 1002                     0.00000
#
#       total_transactions_(including_tnx_to_create_contract  total_Ether_sent  \
# 2859                                                     4         100.99902
# 2149                                                     3           6.92436
# 2979                                                  1443        1047.66474
# 185                                                      6          30.12108
# 1002                                                   161           0.00000
#
#       total_ether_received  total_ether_sent_contracts  total_ether_balance  \
# 2859             101.00000                     0.00000              0.00098
# 2149               6.92485                     0.00000              0.00049
# 2979            1254.78214                     0.00000            207.11740
# 185               30.12225                     0.00000              0.00117
# 1002             431.79653                     0.00000            431.79653
#
#       Total_ERC20_tnxs  ERC20_total_Ether_received  ERC20_total_ether_sent  \
# 2859           0.00000                     0.00000                 0.00000
# 2149           0.00000                     0.00000                 0.00000
# 2979          31.00000               2547558.02500               387.73596
# 185            0.00000                     0.00000                 0.00000
# 1002           3.00000                    14.09318                 0.00000
#
#       ERC20_total_Ether_sent_contract  ERC20_uniq_sent_addr  \
# 2859                          0.00000               0.00000
# 2149                          0.00000               0.00000
# 2979                          0.00000               1.00000
# 185                           0.00000               0.00000
# 1002                          0.00000               0.00000
#
#       ERC20_uniq_rec_addr  ERC20_uniq_sent_addr.1  \
# 2859              0.00000                 0.00000
# 2149              0.00000                 0.00000
# 2979             19.00000                 0.00000
# 185               0.00000                 0.00000
# 1002              3.00000                 0.00000
#
#       ERC20_uniq_rec_contract_addr  ERC20_min_val_rec  ERC20_max_val_rec  \
# 2859                       0.00000            0.00000            0.00000
# 2149                       0.00000            0.00000            0.00000
# 2979                      23.00000            0.00000      2537935.00000
# 185                        0.00000            0.00000            0.00000
# 1002                       3.00000            1.07236           11.46613
#
#       ERC20_avg_val_rec  ERC20_min_val_sent  ERC20_max_val_sent  \
# 2859            0.00000             0.00000             0.00000
# 2149            0.00000             0.00000             0.00000
# 2979        87846.82844             0.70000           387.03596
# 185             0.00000             0.00000             0.00000
# 1002            4.69773             0.00000             0.00000
#
#       ERC20_avg_val_sent  ERC20_uniq_sent_token_name  \
# 2859             0.00000                     0.00000
# 2149             0.00000                     0.00000
# 2979           193.86798                     1.00000
# 185              0.00000                     0.00000
# 1002             0.00000                     0.00000
#
#       ERC20_uniq_rec_token_name ERC20_most_sent_token_type  \
# 2859                    0.00000             no information
# 2149                    0.00000             no information
# 2979                   23.00000                      Golem
# 185                     0.00000             no information
# 1002                    3.00000             no information
#
#      ERC20_most_rec_token_type
# 2859            no information
# 2149            no information
# 2979                     Golem
# 185             no information
# 1002                  DATAcoin

# %% [markdown]
# ## Preprocessing

# %%
lst_numerical_columns = df_cleaned_train_exp_02.drop(columns=[
    'FLAG', 'ERC20_most_sent_token_type', 'ERC20_most_rec_token_type'
]).columns.tolist()

lst_categorical_columns = ['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']

pipe = Pipeline([
    ('rare', RareLabelEncoder(
        n_categories=2, max_n_categories=3, replace_with='rare', tol=0.1,
        variables=['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']
    )),
    ('frq', CountFrequencyEncoder(
        encoding_method='frequency',
        variables=['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']
    )),
    ('imputer', MeanMedianImputer(
        imputation_method='median',
        variables=lst_numerical_columns
    ))
])

df_cleaned_train_exp_02_transformed = pipe.fit_transform(df_cleaned_train_exp_02)
df_cleaned_test_exp_02_transformed = pipe.transform(df_cleaned_test_exp_02)

display(df_cleaned_train_exp_02_transformed['ERC20_most_rec_token_type'].value_counts())
display(df_cleaned_train_exp_02_transformed['ERC20_most_sent_token_type'].value_counts())
# Out:
# ERC20_most_rec_token_type
# 0.53506    4464
# 0.46494    3879
# Name: count, dtype: int64
# ERC20_most_sent_token_type
# 0.84238    7028
# 0.15762    1315
# Name: count, dtype: int64

# %% [markdown]
# ### Effect of transformation over numerical features
#
# #### Training dataset

# %%
df_num_features_before_transf = df_cleaned_train_exp_02.loc[:, lst_numerical_columns].describe().T[['count', 'mean', 'std', '50%']]
df_num_features_after_transf = df_cleaned_train_exp_02_transformed.loc[:, lst_numerical_columns].describe().T[['count', 'mean', 'std', '50%']]

pd.concat([df_num_features_before_transf, df_num_features_after_transf], axis=1)
# .to_excel(PROCESSED_FOLDER + 'df_after_preprocessing.xlsx')
# Out:
#                                                           count  \
# Avg_min_between_sent_tnx                             8343.00000
# Avg_min_between_received_tnx                         8343.00000
# Time_Diff_between_first_and_last_(Mins)              8343.00000
# Sent_tnx                                             8343.00000
# Received_Tnx                                         8343.00000
# Number_of_Created_Contracts                          8343.00000
# Unique_Received_From_Addresses                       8343.00000
# Unique_Sent_To_Addresses                             8343.00000
# min_value_received                                   8343.00000
# max_value_received                                   8343.00000
# avg_val_received                                     8343.00000
# min_val_sent                                         8343.00000
# max_val_sent                                         8343.00000
# avg_val_sent                                         8343.00000
# min_value_sent_to_contract                           8343.00000
# max_val_sent_to_contract                             8343.00000
# avg_value_sent_to_contract                           8343.00000
# total_transactions_(including_tnx_to_create_contract 8343.00000
# total_Ether_sent                                     8343.00000
# total_ether_received                                 8343.00000
# total_ether_sent_contracts                           8343.00000
# total_ether_balance                                  8343.00000
# Total_ERC20_tnxs                                     7648.00000
# ERC20_total_Ether_received                           7648.00000
# ERC20_total_ether_sent                               7648.00000
# ERC20_total_Ether_sent_contract                      7648.00000
# ERC20_uniq_sent_addr                                 7648.00000
# ERC20_uniq_rec_addr                                  7648.00000
# ERC20_uniq_sent_addr.1                               7648.00000
# ERC20_uniq_rec_contract_addr                         7648.00000
# ERC20_min_val_rec                                    7648.00000
# ERC20_max_val_rec                                    7648.00000
# ERC20_avg_val_rec                                    7648.00000
# ERC20_min_val_sent                                   7648.00000
# ERC20_max_val_sent                                   7648.00000
# ERC20_avg_val_sent                                   7648.00000
# ERC20_uniq_sent_token_name                           7648.00000
# ERC20_uniq_rec_token_name                            7648.00000
#
#                                                                 mean  \
# Avg_min_between_sent_tnx                                  5030.61067
# Avg_min_between_received_tnx                              7989.67142
# Time_Diff_between_first_and_last_(Mins)                 219932.64152
# Sent_tnx                                                   120.88541
# Received_Tnx                                               166.82776
# Number_of_Created_Contracts                                  3.78006
# Unique_Received_From_Addresses                              31.34939
# Unique_Sent_To_Addresses                                    27.10080
# min_value_received                                          45.00561
# max_value_received                                         556.19442
# avg_val_received                                           107.97405
# min_val_sent                                                 5.20611
# max_val_sent                                               277.93312
# avg_val_sent                                                45.45962
# min_value_sent_to_contract                                   0.00000
# max_val_sent_to_contract                                     0.00001
# avg_value_sent_to_contract                                   0.00001
# total_transactions_(including_tnx_to_create_contract       291.49323
# total_Ether_sent                                          9914.01920
# total_ether_received                                     13372.52295
# total_ether_sent_contracts                                   0.00001
# total_ether_balance                                       3458.50374
# Total_ERC20_tnxs                                            37.41684
# ERC20_total_Ether_received                           149124532.66158
# ERC20_total_ether_sent                                16215621.84245
# ERC20_total_Ether_sent_contract                             73.76086
# ERC20_uniq_sent_addr                                         5.84440
# ERC20_uniq_rec_addr                                          7.68475
# ERC20_uniq_sent_addr.1                                       0.00327
# ERC20_uniq_rec_contract_addr                                 4.92835
# ERC20_min_val_rec                                          563.81598
# ERC20_max_val_rec                                    144722197.27775
# ERC20_avg_val_rec                                      4982994.78938
# ERC20_min_val_sent                                       13823.94988
# ERC20_max_val_sent                                    15287166.44318
# ERC20_avg_val_sent                                     7436992.48011
# ERC20_uniq_sent_token_name                                   1.39108
# ERC20_uniq_rec_token_name                                    4.85068
#
#                                                                    std  \
# Avg_min_between_sent_tnx                                   21578.15147
# Avg_min_between_received_tnx                               23008.38888
# Time_Diff_between_first_and_last_(Mins)                   325301.55593
# Sent_tnx                                                     771.23614
# Received_Tnx                                                 941.89285
# Number_of_Created_Contracts                                  148.75941
# Unique_Received_From_Addresses                               306.65191
# Unique_Sent_To_Addresses                                     278.24392
# min_value_received                                           343.07167
# max_value_received                                         13854.83002
# avg_val_received                                            3131.54552
# min_val_sent                                                 150.45278
# max_val_sent                                                4391.54843
# avg_val_sent                                                 252.23085
# min_value_sent_to_contract                                     0.00024
# max_val_sent_to_contract                                       0.00056
# avg_value_sent_to_contract                                     0.00035
# total_transactions_(including_tnx_to_create_contract        1364.80460
# total_Ether_sent                                          349664.23948
# total_ether_received                                      395350.03168
# total_ether_sent_contracts                                     0.00056
# total_ether_balance                                       199985.50729
# Total_ERC20_tnxs                                             453.31957
# ERC20_total_Ether_received                           11439013441.43275
# ERC20_total_ether_sent                                1281326032.77154
# ERC20_total_Ether_sent_contract                             4648.22695
# ERC20_uniq_sent_addr                                         110.83968
# ERC20_uniq_rec_addr                                           85.12206
# ERC20_uniq_sent_addr.1                                         0.06561
# ERC20_uniq_rec_contract_addr                                  17.84116
# ERC20_min_val_rec                                          18324.05420
# ERC20_max_val_rec                                    11437871567.25698
# ERC20_avg_val_rec                                      232323126.52313
# ERC20_min_val_sent                                       1143663.77378
# ERC20_max_val_sent                                    1280802561.90442
# ERC20_avg_val_sent                                     642057431.17097
# ERC20_uniq_sent_token_name                                     6.95914
# ERC20_uniq_rec_token_name                                     17.23474
#
#                                                              50%      count  \
# Avg_min_between_sent_tnx                                16.88000 8343.00000
# Avg_min_between_received_tnx                           503.66000 8343.00000
# Time_Diff_between_first_and_last_(Mins)              46352.60000 8343.00000
# Sent_tnx                                                 3.00000 8343.00000
# Received_Tnx                                             4.00000 8343.00000
# Number_of_Created_Contracts                              0.00000 8343.00000
# Unique_Received_From_Addresses                           2.00000 8343.00000
# Unique_Sent_To_Addresses                                 2.00000 8343.00000
# min_value_received                                       0.09500 8343.00000
# max_value_received                                       5.99954 8343.00000
# avg_val_received                                         1.70652 8343.00000
# min_val_sent                                             0.04958 8343.00000
# max_val_sent                                             4.99453 8343.00000
# avg_val_sent                                             1.55085 8343.00000
# min_value_sent_to_contract                               0.00000 8343.00000
# max_val_sent_to_contract                                 0.00000 8343.00000
# avg_value_sent_to_contract                               0.00000 8343.00000
# total_transactions_(including_tnx_to_create_contract     8.00000 8343.00000
# total_Ether_sent                                        12.32657 8343.00000
# total_ether_received                                    30.39022 8343.00000
# total_ether_sent_contracts                               0.00000 8343.00000
# total_ether_balance                                      0.00172 8343.00000
# Total_ERC20_tnxs                                         1.00000 8343.00000
# ERC20_total_Ether_received                               0.00000 8343.00000
# ERC20_total_ether_sent                                   0.00000 8343.00000
# ERC20_total_Ether_sent_contract                          0.00000 8343.00000
# ERC20_uniq_sent_addr                                     0.00000 8343.00000
# ERC20_uniq_rec_addr                                      1.00000 8343.00000
# ERC20_uniq_sent_addr.1                                   0.00000 8343.00000
# ERC20_uniq_rec_contract_addr                             1.00000 8343.00000
# ERC20_min_val_rec                                        0.00000 8343.00000
# ERC20_max_val_rec                                        0.00000 8343.00000
# ERC20_avg_val_rec                                        0.00000 8343.00000
# ERC20_min_val_sent                                       0.00000 8343.00000
# ERC20_max_val_sent                                       0.00000 8343.00000
# ERC20_avg_val_sent                                       0.00000 8343.00000
# ERC20_uniq_sent_token_name                               0.00000 8343.00000
# ERC20_uniq_rec_token_name                                1.00000 8343.00000
#
#                                                                 mean  \
# Avg_min_between_sent_tnx                                  5030.61067
# Avg_min_between_received_tnx                              7989.67142
# Time_Diff_between_first_and_last_(Mins)                 219932.64152
# Sent_tnx                                                   120.88541
# Received_Tnx                                               166.82776
# Number_of_Created_Contracts                                  3.78006
# Unique_Received_From_Addresses                              31.34939
# Unique_Sent_To_Addresses                                    27.10080
# min_value_received                                          45.00561
# max_value_received                                         556.19442
# avg_val_received                                           107.97405
# min_val_sent                                                 5.20611
# max_val_sent                                               277.93312
# avg_val_sent                                                45.45962
# min_value_sent_to_contract                                   0.00000
# max_val_sent_to_contract                                     0.00001
# avg_value_sent_to_contract                                   0.00001
# total_transactions_(including_tnx_to_create_contract       291.49323
# total_Ether_sent                                          9914.01920
# total_ether_received                                     13372.52295
# total_ether_sent_contracts                                   0.00001
# total_ether_balance                                       3458.50374
# Total_ERC20_tnxs                                            34.38320
# ERC20_total_Ether_received                           136701956.82557
# ERC20_total_ether_sent                                14864805.92725
# ERC20_total_Ether_sent_contract                             67.61633
# ERC20_uniq_sent_addr                                         5.35755
# ERC20_uniq_rec_addr                                          7.12789
# ERC20_uniq_sent_addr.1                                       0.00300
# ERC20_uniq_rec_contract_addr                                 4.60110
# ERC20_min_val_rec                                          516.84821
# ERC20_max_val_rec                                    132666350.80669
# ERC20_avg_val_rec                                      4567894.54023
# ERC20_min_val_sent                                       12672.36829
# ERC20_max_val_sent                                    14013693.98987
# ERC20_avg_val_sent                                     6817465.95804
# ERC20_uniq_sent_token_name                                   1.27520
# ERC20_uniq_rec_token_name                                    4.52991
#
#                                                                    std  \
# Avg_min_between_sent_tnx                                   21578.15147
# Avg_min_between_received_tnx                               23008.38888
# Time_Diff_between_first_and_last_(Mins)                   325301.55593
# Sent_tnx                                                     771.23614
# Received_Tnx                                                 941.89285
# Number_of_Created_Contracts                                  148.75941
# Unique_Received_From_Addresses                               306.65191
# Unique_Sent_To_Addresses                                     278.24392
# min_value_received                                           343.07167
# max_value_received                                         13854.83002
# avg_val_received                                            3131.54552
# min_val_sent                                                 150.45278
# max_val_sent                                                4391.54843
# avg_val_sent                                                 252.23085
# min_value_sent_to_contract                                     0.00024
# max_val_sent_to_contract                                       0.00056
# avg_value_sent_to_contract                                     0.00035
# total_transactions_(including_tnx_to_create_contract        1364.80460
# total_Ether_sent                                          349664.23948
# total_ether_received                                      395350.03168
# total_ether_sent_contracts                                     0.00056
# total_ether_balance                                       199985.50729
# Total_ERC20_tnxs                                             434.14184
# ERC20_total_Ether_received                           10952218443.44176
# ERC20_total_ether_sent                                1226797831.44610
# ERC20_total_Ether_sent_contract                             4450.43367
# ERC20_uniq_sent_addr                                         106.13436
# ERC20_uniq_rec_addr                                           81.51999
# ERC20_uniq_sent_addr.1                                         0.06282
# ERC20_uniq_rec_contract_addr                                  17.11626
# ERC20_min_val_rec                                          17544.82931
# ERC20_max_val_rec                                    10951120667.15787
# ERC20_avg_val_rec                                      222439145.78681
# ERC20_min_val_sent                                       1094993.29633
# ERC20_max_val_sent                                    1226295733.32718
# ERC20_avg_val_sent                                     614733324.14003
# ERC20_uniq_sent_token_name                                     6.67402
# ERC20_uniq_rec_token_name                                     16.53546
#
#                                                              50%
# Avg_min_between_sent_tnx                                16.88000
# Avg_min_between_received_tnx                           503.66000
# Time_Diff_between_first_and_last_(Mins)              46352.60000
# Sent_tnx                                                 3.00000
# Received_Tnx                                             4.00000
# Number_of_Created_Contracts                              0.00000
# Unique_Received_From_Addresses                           2.00000
# Unique_Sent_To_Addresses                                 2.00000
# min_value_received                                       0.09500
# max_value_received                                       5.99954
# avg_val_received                                         1.70652
# min_val_sent                                             0.04958
# max_val_sent                                             4.99453
# avg_val_sent                                             1.55085
# min_value_sent_to_contract                               0.00000
# max_val_sent_to_contract                                 0.00000
# avg_value_sent_to_contract                               0.00000
# total_transactions_(including_tnx_to_create_contract     8.00000
# total_Ether_sent                                        12.32657
# total_ether_received                                    30.39022
# total_ether_sent_contracts                               0.00000
# total_ether_balance                                      0.00172
# Total_ERC20_tnxs                                         1.00000
# ERC20_total_Ether_received                               0.00000
# ERC20_total_ether_sent                                   0.00000
# ERC20_total_Ether_sent_contract                          0.00000
# ERC20_uniq_sent_addr                                     0.00000
# ERC20_uniq_rec_addr                                      1.00000
# ERC20_uniq_sent_addr.1                                   0.00000
# ERC20_uniq_rec_contract_addr                             1.00000
# ERC20_min_val_rec                                        0.00000
# ERC20_max_val_rec                                        0.00000
# ERC20_avg_val_rec                                        0.00000
# ERC20_min_val_sent                                       0.00000
# ERC20_max_val_sent                                       0.00000
# ERC20_avg_val_sent                                       0.00000
# ERC20_uniq_sent_token_name                               0.00000
# ERC20_uniq_rec_token_name                                1.00000

# %% [markdown]
# #### Testing dataset

# %%
df_num_features_before_transf = df_cleaned_test_exp_02.loc[:, lst_numerical_columns].describe().T[['count', 'mean', 'std', '50%']]
df_num_features_after_transf = df_cleaned_test_exp_02_transformed.loc[:, lst_numerical_columns].describe().T[['count', 'mean', 'std', '50%']]

pd.concat([df_num_features_before_transf, df_num_features_after_transf], axis=1).to_excel(PROCESSED_FOLDER + 'artigo_df_after_preprocessing.xlsx')

# %%
lst_numeric_columns = df_cleaned_train_exp_02.drop(columns=['FLAG']).select_dtypes(exclude=object).columns.tolist()

pd.DataFrame(
    df_cleaned_train_exp_02_transformed.loc[:, lst_numeric_columns].median(axis=0), columns=['Mediana']
).to_excel(PROCESSED_FOLDER + 'artigo_preprocessing_numerical.xlsx')

# %% [markdown]
# ### Effect of transformation over categorical features
#
# #### Training dataset

# %%
column = 'ERC20_most_rec_token_type'

# Before
df_temp = pd.DataFrame(
    100*df_cleaned_train_exp_02[[column]].value_counts() /\
    df_cleaned_train_exp_02[[column]].value_counts().sum(),
    columns=['Proporção']
)

df_temp['cumsum'] = df_temp['Proporção'].cumsum()
df_temp.to_excel(PROCESSED_FOLDER + f'artigo_before_{column}.xlsx', engine='xlsxwriter')
display(df_temp.head())

# After

display(df_cleaned_train_exp_02_transformed[column].unique())
# Out:
# Empty DataFrame
# Columns: [Proporção, cumsum]
# Index: []
# array([0.53505933, 0.46494067])

# %%
column = 'ERC20_most_sent_token_type'

# Before
df_temp = pd.DataFrame(
    100*df_cleaned_train_exp_02[[column]].value_counts() /\
    df_cleaned_train_exp_02[[column]].value_counts().sum(),
    columns=['Proporção']
)

df_temp['cumsum'] = df_temp['Proporção'].cumsum()
df_temp.to_excel(PROCESSED_FOLDER + f'Before_{column}.xlsx', engine='xlsxwriter')
display(df_temp.head())

# After

display(df_cleaned_train_exp_02_transformed[column].unique())
# Out:
# Empty DataFrame
# Columns: [Proporção, cumsum]
# Index: []
# array([0.89154504, 0.10845496])

# %% [markdown]
# ### Testing dataset

# %%
column = 'ERC20_most_rec_token_type'

# Before
df_temp = pd.DataFrame(
    100*df_cleaned_test_exp_02[[column]].value_counts() /\
    df_cleaned_test_exp_02[[column]].value_counts().sum(),
    columns=['Proporção']
)

df_temp['cumsum'] = df_temp['Proporção'].cumsum()
display(df_temp.head())

# After
display(df_cleaned_test_exp_02_transformed[column].unique())
# Out:
# Empty DataFrame
# Columns: [Proporção, cumsum]
# Index: []
# array([0.46494067, 0.53505933])

# %%
# Before
df_temp = pd.DataFrame(
    100*df_cleaned_test_exp_02[['ERC20_most_sent_token_type']].value_counts() /\
    df_cleaned_test_exp_02[['ERC20_most_sent_token_type']].value_counts().sum(),
    columns=['Proporção']
)

df_temp['cumsum'] = df_temp['Proporção'].cumsum()
display(df_temp.head())

# After
display(df_cleaned_test_exp_02_transformed['ERC20_most_sent_token_type'].unique())
# Out:
# Empty DataFrame
# Columns: [Proporção, cumsum]
# Index: []
# array([0.89154504, 0.10845496])

# %% [markdown]
# ## Exporting

# %%
df_cleaned_train_exp_02_transformed.to_parquet(INTERIM_FOLDER + 'artigo_df_cleaned_train_exp_02_transformed.pqt')
df_cleaned_test_exp_02_transformed.to_parquet(INTERIM_FOLDER + 'artigo_df_cleaned_test_exp_02_transformed.pqt')
